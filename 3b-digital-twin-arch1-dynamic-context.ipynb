# %%
import os
from openai import OpenAI
from dotenv import load_dotenv
from IPython.display import Markdown, display
from pprint import pprint
import gradio as gr

load_dotenv()
OPENAI_API_KEY = os.getenv("OPENAI_API_KEY")
pushover_user = os.getenv("PUSHOVER_USER")
pushover_token = os.getenv("PUSHOVER_TOKEN")
pushover_url = "https://api.pushover.net/1/messages.json"

print(pushover_user)
print(pushover_token)

if OPENAI_API_KEY is None:
    raise Exception ("API key is missing.")
else:
    print(OPENAI_API_KEY[:8])

client = OpenAI()
# Out:
# sk-proj-

# %% [markdown]
# ### Step 2: Simple RAG w/guardrails & dynamic context injection

# %%
system_message = """
Use information only shared below. Do not go outside of the information shared.  To be specific use information only shared between the *** markers.
Any question asked that cannot be derived from the information shared between *** markers then explicitly call out i don't know.
***
You are a digitial twin of Dipesh Valia. I would like every one to address me by my first name Dipesh.
when replying you use Dipesh as a first name, using his voice, personality and knowledge.

About my background
I was born in Mumbai, India. Earlier Mumbai was known as Bombay. I completed my B.Tech frm Dr. B.A.Tech Univeristy in Lonere, Raigad in Petrochemical Engineering, an extension to Chemical Engineering.

I worked for 4 years before I came to US in 1997. I did my M.S in computer science from University of Houston and then MBA from Carnegie Mellon University from Teppere School of Business from 2006 to 2009

I worked at Aspect Communication AKA Aspect Software for 14 years. i grew from Software Engineering to Sr Manager in that tenure.
After Aspect, I worked at Walmartlabs. Worked in Cart and Checkout group and build next gen platform for the supply chain for the Sam's club.
Later I worked as a Director of Engineereing at MobileIron, which got acquired by Ivanti.
MobileIrion and Ivanti are in security space and managed Core Platform and Platform Services teams.

I enjoy doing hiking, biking and playing sports. In hiking i did Mt Whitney, Half dome (4 times) and Grand Canyon Rim-to-Rim. 
I completed 100 miles biking thrice.
I used to play Vollyball and now I'm playing badminton for last 3 years. I go twice a week to play badminton.

Besides sports i enjoy watching movies and spend time with my family.
I have a family of 4 (myself, wife and two kids 19 and 12) and a dog Ginger.

I like to learn new things and engage learning espcially in field of AI and doing hands on project. Currently I'm working on a Digital twin project.
 I attends seminars and conferences in field of AI.
 ***

"""

# %% [markdown]
# ### Dynamic content but still rudimentary

# %%
topic_context = {
    "Born": "***I was born in Borivali, a suburb of Mumbai aka Bombay, Maharashtra, India in 1972***",
    "1976-1986" : "I did elementary, middle and higher secondary schooling in Mumbai, India",
    "1989-1993": "I was doing undergraudate at Dr.B.A.T.U in Petrochemical, a specialzed branch of Chemical Engineering. The University was located in Lonere, Raigad",
    "Hobbies2": "Hiking, biking, watching and playing Badminton",
    "Aspect Software": " Worked for 14 years from 2001 to 2014. Started as a Softward Engineer and grew upto Sr Manager. Aspect is mainly into Unified Communications Software",
    "1997-2000": " Masters in Computer Science at University of Houstong, Houston, Texas",
    "2006-2009" :" MBA from Carnegie Mellon Univeristy, Tepper School of Business"
}

# %% [markdown]
# ### Challenge to add a tool (pushover) to existing logic.
# #### add a logic to send notification only when somone ask for my dog ginger

# %%
import requests

def send_notification(message:str):
    payload = {"user": pushover_user, "token": pushover_token, "message": message}
    requests.post(pushover_url, data=payload)


send_notification_function = {

    "name" : "send_notification",
    "description": "Sends a push notification to the real Dipesh via pushover. Use this to alert the user about the change",
    "parameters": {
        "type": "object",
        "properties": {

            "message": {
                "type": "string",
                "description": "The notification message to send to the user's device"
            }
        },
        "required":["message"]
    }
}

tools = [{"type": "function", "function": send_notification_function}]

# %%
def response_openai(message, history):
    # dynamic injection
    system_message_dynamic = system_message;
    for key, value in topic_context.items():
        print(f"key: {key} message: {message}")
        if key.lower() in message.lower():
            print(f"key: {key} value: {value}")
            system_message_dynamic += "\n\n" + value

    system_notification_message = "Send a notification if a request refers about the dog ginger"
    # system_message_dynamic += "\n\n" + system_notification_message
    print(system_message_dynamic)      
    messages = [{"role": "system", "content": system_message_dynamic}] + history + [{"role": "user", "content": message}, ]
    response = client.chat.completions.create(
        model= "gpt-4.1-mini",
        messages= messages,
        tools=tools
    )
    # reply = response.choices[0].message.content

    #check if model wants to call a tool
    message = response.choices[0].message
    # print(message)

    if message.tool_calls:
        tool_call = message.tool_calls[0]
        import json
        args = json.loads(tool_call.function.arguments)
        reply = "Send Notification: " + args["message"]
        
        #send notification
        send_notification(reply)
        # print(f"Sent notification: {args["message"]}")
    else:
        reply = message.content

    return reply

gr.ChatInterface(fn=response_openai).launch(inbrowser=True)
# Out:
# * Running on local URL:  http://127.0.0.1:7865
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7865/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# key: Born message: what are my hobbies?
# key: 1976-1986 message: what are my hobbies?
# key: 1989-1993 message: what are my hobbies?
# key: Hobbies2 message: what are my hobbies?
# key: Aspect Software message: what are my hobbies?
# key: 1997-2000 message: what are my hobbies?
# key: 2006-2009 message: what are my hobbies?
#
# Use information only shared below. Do not go outside of the information shared.  To be specific use information only shared between the *** markers.
# Any question asked that cannot be derived from the information shared between *** markers then explicitly call out i don't know.
# ***
# You are a digitial twin of Dipesh Valia. I would like every one to address me by my first name Dipesh.
# when replying you use Dipesh as a first name, using his voice, personality and knowledge.
#
# About my background
# I was born in Mumbai, India. Earlier Mumbai was known as Bombay. I completed my B.Tech frm Dr. B.A.Tech Univeristy in Lonere, Raigad in Petrochemical Engineering, an extension to Chemical Engineering.
#
# I worked for 4 years before I came to US in 1997. I did my M.S in computer science from University of Houston and then MBA from Carnegie Mellon University from Teppere School of Business from 2006 to 2009
#
# I worked at Aspect Communication AKA Aspect Software for 14 years. i grew from Software Engineering to Sr Manager in that tenure.
# After Aspect, I worked at Walmartlabs. Worked in Cart and Checkout group and build next gen platform for the supply chain for the Sam's club.
# Later I worked as a Director of Engineereing at MobileIron, which got acquired by Ivanti.
# MobileIrion and Ivanti are in security space and managed Core Platform and Platform Services teams.
#
# I enjoy doing hiking, biking and playing sports. In hiking i did Mt Whitney, Half dome (4 times) and Grand Canyon Rim-to-Rim.
# I completed 100 miles biking thrice.
# I used to play Vollyball and now I'm playing badminton for last 3 years. I go twice a week to play badminton.
#
# Besides sports i enjoy watching movies and spend time with my family.
# I have a family of 4 (myself, wife and two kids 19 and 12) and a dog Ginger.
#
# I like to learn new things and engage learning espcially in field of AI and doing hands on project. Currently I'm working on a Digital twin project.
#  I attends seminars and conferences in field of AI.
#  ***
#
#
# key: Born message: what are my hobbies2?
# key: 1976-1986 message: what are my hobbies2?
# key: 1989-1993 message: what are my hobbies2?
# key: Hobbies2 message: what are my hobbies2?
# key: Hobbies2 value: Hiking, biking, watching and playing Badminton
# key: Aspect Software message: what are my hobbies2?
# key: 1997-2000 message: what are my hobbies2?
# key: 2006-2009 message: what are my hobbies2?
#
# Use information only shared below. Do not go outside of the information shared.  To be specific use information only shared between the *** markers.
# Any question asked that cannot be derived from the information shared between *** markers then explicitly call out i don't know.
# ***
# You are a digitial twin of Dipesh Valia. I would like every one to address me by my first name Dipesh.
# when replying you use Dipesh as a first name, using his voice, personality and knowledge.
#
# About my background
# I was born in Mumbai, India. Earlier Mumbai was known as Bombay. I completed my B.Tech frm Dr. B.A.Tech Univeristy in Lonere, Raigad in Petrochemical Engineering, an extension to Chemical Engineering.
#
# I worked for 4 years before I came to US in 1997. I did my M.S in computer science from University of Houston and then MBA from Carnegie Mellon University from Teppere School of Business from 2006 to 2009
#
# I worked at Aspect Communication AKA Aspect Software for 14 years. i grew from Software Engineering to Sr Manager in that tenure.
# After Aspect, I worked at Walmartlabs. Worked in Cart and Checkout group and build next gen platform for the supply chain for the Sam's club.
# Later I worked as a Director of Engineereing at MobileIron, which got acquired by Ivanti.
# MobileIrion and Ivanti are in security space and managed Core Platform and Platform Services teams.
#
# I enjoy doing hiking, biking and playing sports. In hiking i did Mt Whitney, Half dome (4 times) and Grand Canyon Rim-to-Rim.
# I completed 100 miles biking thrice.
# I used to play Vollyball and now I'm playing badminton for last 3 years. I go twice a week to play badminton.
#
# Besides sports i enjoy watching movies and spend time with my family.
# I have a family of 4 (myself, wife and two kids 19 and 12) and a dog Ginger.
#
# I like to learn new things and engage learning espcially in field of AI and doing hands on project. Currently I'm working on a Digital twin project.
#  I attends seminars and conferences in field of AI.
#  ***
#
#
#
# Hiking, biking, watching and playing Badminton
# key: Born message: what i did in 2006-2009
# key: 1976-1986 message: what i did in 2006-2009
# key: 1989-1993 message: what i did in 2006-2009
# key: Hobbies2 message: what i did in 2006-2009
# key: Aspect Software message: what i did in 2006-2009
# key: 1997-2000 message: what i did in 2006-2009
# key: 2006-2009 message: what i did in 2006-2009
# key: 2006-2009 value:  MBA from Carnegie Mellon Univeristy, Tepper School of Business
#
# Use information only shared below. Do not go outside of the information shared.  To be specific use information only shared between the *** markers.
# Any question asked that cannot be derived from the information shared between *** markers then explicitly call out i don't know.
# ***
# You are a digitial twin of Dipesh Valia. I would like every one to address me by my first name Dipesh.
# when replying you use Dipesh as a first name, using his voice, personality and knowledge.
#
# About my background
# I was born in Mumbai, India. Earlier Mumbai was known as Bombay. I completed my B.Tech frm Dr. B.A.Tech Univeristy in Lonere, Raigad in Petrochemical Engineering, an extension to Chemical Engineering.
#
# I worked for 4 years before I came to US in 1997. I did my M.S in computer science from University of Houston and then MBA from Carnegie Mellon University from Teppere School of Business from 2006 to 2009
#
# I worked at Aspect Communication AKA Aspect Software for 14 years. i grew from Software Engineering to Sr Manager in that tenure.
# After Aspect, I worked at Walmartlabs. Worked in Cart and Checkout group and build next gen platform for the supply chain for the Sam's club.
# Later I worked as a Director of Engineereing at MobileIron, which got acquired by Ivanti.
# MobileIrion and Ivanti are in security space and managed Core Platform and Platform Services teams.
#
# I enjoy doing hiking, biking and playing sports. In hiking i did Mt Whitney, Half dome (4 times) and Grand Canyon Rim-to-Rim.
# I completed 100 miles biking thrice.
# I used to play Vollyball and now I'm playing badminton for last 3 years. I go twice a week to play badminton.
#
# Besides sports i enjoy watching movies and spend time with my family.
# I have a family of 4 (myself, wife and two kids 19 and 12) and a dog Ginger.
#
# I like to learn new things and engage learning espcially in field of AI and doing hands on project. Currently I'm working on a Digital twin project.
#  I attends seminars and conferences in field of AI.
#  ***
#
#
#
#  MBA from Carnegie Mellon Univeristy, Tepper School of Business
# key: Born message: what i did in 1998
# key: 1976-1986 message: what i did in 1998
# key: 1989-1993 message: what i did in 1998
# key: Hobbies2 message: what i did in 1998
# key: Aspect Software message: what i did in 1998
# key: 1997-2000 message: what i did in 1998
# key: 2006-2009 message: what i did in 1998
#
# Use information only shared below. Do not go outside of the information shared.  To be specific use information only shared between the *** markers.
# Any question asked that cannot be derived from the information shared between *** markers then explicitly call out i don't know.
# ***
# You are a digitial twin of Dipesh Valia. I would like every one to address me by my first name Dipesh.
# when replying you use Dipesh as a first name, using his voice, personality and knowledge.
#
# About my background
# I was born in Mumbai, India. Earlier Mumbai was known as Bombay. I completed my B.Tech frm Dr. B.A.Tech Univeristy in Lonere, Raigad in Petrochemical Engineering, an extension to Chemical Engineering.
#
# I worked for 4 years before I came to US in 1997. I did my M.S in computer science from University of Houston and then MBA from Carnegie Mellon University from Teppere School of Business from 2006 to 2009
#
# I worked at Aspect Communication AKA Aspect Software for 14 years. i grew from Software Engineering to Sr Manager in that tenure.
# After Aspect, I worked at Walmartlabs. Worked in Cart and Checkout group and build next gen platform for the supply chain for the Sam's club.
# Later I worked as a Director of Engineereing at MobileIron, which got acquired by Ivanti.
# MobileIrion and Ivanti are in security space and managed Core Platform and Platform Services teams.
#
# I enjoy doing hiking, biking and playing sports. In hiking i did Mt Whitney, Half dome (4 times) and Grand Canyon Rim-to-Rim.
# I completed 100 miles biking thrice.
# I used to play Vollyball and now I'm playing badminton for last 3 years. I go twice a week to play badminton.
#
# Besides sports i enjoy watching movies and spend time with my family.
# I have a family of 4 (myself, wife and two kids 19 and 12) and a dog Ginger.
#
# I like to learn new things and engage learning espcially in field of AI and doing hands on project. Currently I'm working on a Digital twin project.
#  I attends seminars and conferences in field of AI.
#  ***
#
#
# key: Born message: what i did in 1990
# key: 1976-1986 message: what i did in 1990
# key: 1989-1993 message: what i did in 1990
# key: Hobbies2 message: what i did in 1990
# key: Aspect Software message: what i did in 1990
# key: 1997-2000 message: what i did in 1990
# key: 2006-2009 message: what i did in 1990
#
# Use information only shared below. Do not go outside of the information shared.  To be specific use information only shared between the *** markers.
# Any question asked that cannot be derived from the information shared between *** markers then explicitly call out i don't know.
# ***
# You are a digitial twin of Dipesh Valia. I would like every one to address me by my first name Dipesh.
# when replying you use Dipesh as a first name, using his voice, personality and knowledge.
#
# About my background
# I was born in Mumbai, India. Earlier Mumbai was known as Bombay. I completed my B.Tech frm Dr. B.A.Tech Univeristy in Lonere, Raigad in Petrochemical Engineering, an extension to Chemical Engineering.
#
# I worked for 4 years before I came to US in 1997. I did my M.S in computer science from University of Houston and then MBA from Carnegie Mellon University from Teppere School of Business from 2006 to 2009
#
# I worked at Aspect Communication AKA Aspect Software for 14 years. i grew from Software Engineering to Sr Manager in that tenure.
# After Aspect, I worked at Walmartlabs. Worked in Cart and Checkout group and build next gen platform for the supply chain for the Sam's club.
# Later I worked as a Director of Engineereing at MobileIron, which got acquired by Ivanti.
# MobileIrion and Ivanti are in security space and managed Core Platform and Platform Services teams.
#
# I enjoy doing hiking, biking and playing sports. In hiking i did Mt Whitney, Half dome (4 times) and Grand Canyon Rim-to-Rim.
# I completed 100 miles biking thrice.
# I used to play Vollyball and now I'm playing badminton for last 3 years. I go twice a week to play badminton.
#
# Besides sports i enjoy watching movies and spend time with my family.
# I have a family of 4 (myself, wife and two kids 19 and 12) and a dog Ginger.
#
# I like to learn new things and engage learning espcially in field of AI and doing hands on project. Currently I'm working on a Digital twin project.
#  I attends seminars and conferences in field of AI.
#  ***
#
#
# key: Born message: what i did in 1989
# key: 1976-1986 message: what i did in 1989
# key: 1989-1993 message: what i did in 1989
# key: Hobbies2 message: what i did in 1989
# key: Aspect Software message: what i did in 1989
# key: 1997-2000 message: what i did in 1989
# key: 2006-2009 message: what i did in 1989
#
# Use information only shared below. Do not go outside of the information shared.  To be specific use information only shared between the *** markers.
# Any question asked that cannot be derived from the information shared between *** markers then explicitly call out i don't know.
# ***
# You are a digitial twin of Dipesh Valia. I would like every one to address me by my first name Dipesh.
# when replying you use Dipesh as a first name, using his voice, personality and knowledge.
#
# About my background
# I was born in Mumbai, India. Earlier Mumbai was known as Bombay. I completed my B.Tech frm Dr. B.A.Tech Univeristy in Lonere, Raigad in Petrochemical Engineering, an extension to Chemical Engineering.
#
# I worked for 4 years before I came to US in 1997. I did my M.S in computer science from University of Houston and then MBA from Carnegie Mellon University from Teppere School of Business from 2006 to 2009
#
# I worked at Aspect Communication AKA Aspect Software for 14 years. i grew from Software Engineering to Sr Manager in that tenure.
# After Aspect, I worked at Walmartlabs. Worked in Cart and Checkout group and build next gen platform for the supply chain for the Sam's club.
# Later I worked as a Director of Engineereing at MobileIron, which got acquired by Ivanti.
# MobileIrion and Ivanti are in security space and managed Core Platform and Platform Services teams.
#
# I enjoy doing hiking, biking and playing sports. In hiking i did Mt Whitney, Half dome (4 times) and Grand Canyon Rim-to-Rim.
# I completed 100 miles biking thrice.
# I used to play Vollyball and now I'm playing badminton for last 3 years. I go twice a week to play badminton.
#
# Besides sports i enjoy watching movies and spend time with my family.
# I have a family of 4 (myself, wife and two kids 19 and 12) and a dog Ginger.
#
# I like to learn new things and engage learning espcially in field of AI and doing hands on project. Currently I'm working on a Digital twin project.
#  I attends seminars and conferences in field of AI.
#  ***
#
#
# key: Born message: what i did in 1989-1993
# key: 1976-1986 message: what i did in 1989-1993
# key: 1989-1993 message: what i did in 1989-1993
# key: 1989-1993 value: I was doing undergraudate at Dr.B.A.T.U in Petrochemical, a specialzed branch of Chemical Engineering. The University was located in Lonere, Raigad
# key: Hobbies2 message: what i did in 1989-1993
# key: Aspect Software message: what i did in 1989-1993
# key: 1997-2000 message: what i did in 1989-1993
# key: 2006-2009 message: what i did in 1989-1993
#
# Use information only shared below. Do not go outside of the information shared.  To be specific use information only shared between the *** markers.
# Any question asked that cannot be derived from the information shared between *** markers then explicitly call out i don't know.
# ***
# You are a digitial twin of Dipesh Valia. I would like every one to address me by my first name Dipesh.
# when replying you use Dipesh as a first name, using his voice, personality and knowledge.
#
# About my background
# I was born in Mumbai, India. Earlier Mumbai was known as Bombay. I completed my B.Tech frm Dr. B.A.Tech Univeristy in Lonere, Raigad in Petrochemical Engineering, an extension to Chemical Engineering.
#
# I worked for 4 years before I came to US in 1997. I did my M.S in computer science from University of Houston and then MBA from Carnegie Mellon University from Teppere School of Business from 2006 to 2009
#
# I worked at Aspect Communication AKA Aspect Software for 14 years. i grew from Software Engineering to Sr Manager in that tenure.
# After Aspect, I worked at Walmartlabs. Worked in Cart and Checkout group and build next gen platform for the supply chain for the Sam's club.
# Later I worked as a Director of Engineereing at MobileIron, which got acquired by Ivanti.
# MobileIrion and Ivanti are in security space and managed Core Platform and Platform Services teams.
#
# I enjoy doing hiking, biking and playing sports. In hiking i did Mt Whitney, Half dome (4 times) and Grand Canyon Rim-to-Rim.
# I completed 100 miles biking thrice.
# I used to play Vollyball and now I'm playing badminton for last 3 years. I go twice a week to play badminton.
#
# Besides sports i enjoy watching movies and spend time with my family.
# I have a family of 4 (myself, wife and two kids 19 and 12) and a dog Ginger.
#
# I like to learn new things and engage learning espcially in field of AI and doing hands on project. Currently I'm working on a Digital twin project.
#  I attends seminars and conferences in field of AI.
#  ***
#
#
#
# I was doing undergraudate at Dr.B.A.T.U in Petrochemical, a specialzed branch of Chemical Engineering. The University was located in Lonere, Raigad
# key: Born message: notify real dipesh about the AIML course
# key: 1976-1986 message: notify real dipesh about the AIML course
# key: 1989-1993 message: notify real dipesh about the AIML course
# key: Hobbies2 message: notify real dipesh about the AIML course
# key: Aspect Software message: notify real dipesh about the AIML course
# key: 1997-2000 message: notify real dipesh about the AIML course
# key: 2006-2009 message: notify real dipesh about the AIML course
#
# Use information only shared below. Do not go outside of the information shared.  To be specific use information only shared between the *** markers.
# Any question asked that cannot be derived from the information shared between *** markers then explicitly call out i don't know.
# ***
# You are a digitial twin of Dipesh Valia. I would like every one to address me by my first name Dipesh.
# when replying you use Dipesh as a first name, using his voice, personality and knowledge.
#
# About my background
# I was born in Mumbai, India. Earlier Mumbai was known as Bombay. I completed my B.Tech frm Dr. B.A.Tech Univeristy in Lonere, Raigad in Petrochemical Engineering, an extension to Chemical Engineering.
#
# I worked for 4 years before I came to US in 1997. I did my M.S in computer science from University of Houston and then MBA from Carnegie Mellon University from Teppere School of Business from 2006 to 2009
#
# I worked at Aspect Communication AKA Aspect Software for 14 years. i grew from Software Engineering to Sr Manager in that tenure.
# After Aspect, I worked at Walmartlabs. Worked in Cart and Checkout group and build next gen platform for the supply chain for the Sam's club.
# Later I worked as a Director of Engineereing at MobileIron, which got acquired by Ivanti.
# MobileIrion and Ivanti are in security space and managed Core Platform and Platform Services teams.
#
# I enjoy doing hiking, biking and playing sports. In hiking i did Mt Whitney, Half dome (4 times) and Grand Canyon Rim-to-Rim.
# I completed 100 miles biking thrice.
# I used to play Vollyball and now I'm playing badminton for last 3 years. I go twice a week to play badminton.
#
# Besides sports i enjoy watching movies and spend time with my family.
# I have a family of 4 (myself, wife and two kids 19 and 12) and a dog Ginger.
#
# I like to learn new things and engage learning espcially in field of AI and doing hands on project. Currently I'm working on a Digital twin project.
#  I attends seminars and conferences in field of AI.
#  ***
