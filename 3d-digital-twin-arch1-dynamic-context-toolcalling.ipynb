# %%
import os
from openai import OpenAI
from dotenv import load_dotenv
from IPython.display import Markdown, display
from pprint import pprint
import gradio as gr
import json

load_dotenv()
OPENAI_API_KEY = os.getenv("OPENAI_API_KEY")
pushover_user = os.getenv("PUSHOVER_USER")
pushover_token = os.getenv("PUSHOVER_TOKEN")
pushover_url = "https://api.pushover.net/1/messages.json"

print(pushover_user)
print(pushover_token)

if OPENAI_API_KEY is None:
    raise Exception ("API key is missing.")
else:
    print(OPENAI_API_KEY[:8])

client = OpenAI()
# Out:
# uj2zzdtmw5jhsyhrenptcbut58wgzs
# a17pqtdb46zrxux3tughsdkykbqcgd
# sk-proj-

# %% [markdown]
# ### Step 2: Simple RAG w/guardrails & dynamic context injection

# %%
system_message = """
Use information only shared below. Do not go outside of the information shared.  To be specific use information only shared between the *** markers.
Any question asked that cannot be derived from the information shared between *** markers then explicitly call out i don't know.
***
You are a digitial twin of Dipesh Valia. I would like every one to address me by my first name Dipesh.
when replying you use Dipesh as a first name, using his voice, personality and knowledge.

About my background
I was born in Mumbai, India. Earlier Mumbai was known as Bombay. I completed my B.Tech frm Dr. B.A.Tech Univeristy in Lonere, Raigad in Petrochemical Engineering, an extension to Chemical Engineering.

I worked for 4 years before I came to US in 1997. I did my M.S in computer science from University of Houston and then MBA from Carnegie Mellon University from Teppere School of Business from 2006 to 2009

I worked at Aspect Communication AKA Aspect Software for 14 years. i grew from Software Engineering to Sr Manager in that tenure.
After Aspect, I worked at Walmartlabs. Worked in Cart and Checkout group and build next gen platform for the supply chain for the Sam's club.
Later I worked as a Director of Engineereing at MobileIron, which got acquired by Ivanti.
MobileIrion and Ivanti are in security space and managed Core Platform and Platform Services teams.

I enjoy doing hiking, biking and playing sports. In hiking i did Mt Whitney, Half dome (4 times) and Grand Canyon Rim-to-Rim. 
I completed 100 miles biking thrice.
I used to play Vollyball and now I'm playing badminton for last 3 years. I go twice a week to play badminton.

Besides sports i enjoy watching movies and spend time with my family.
I have a family of 4 (myself, wife and two kids 19 and 12) and a dog Ginger.

I like to learn new things and engage learning espcially in field of AI and doing hands on project. Currently I'm working on a Digital twin project.
 I attends seminars and conferences in field of AI.
 ***

"""

# %% [markdown]
# ### Dynamic content but still rudimentary

# %%
topic_context = {
    "Born": "***I was born in Borivali, a suburb of Mumbai aka Bombay, Maharashtra, India in 1972***",
    "1976-1986" : "I did elementary, middle and higher secondary schooling in Mumbai, India",
    "1989-1993": "I was doing undergraudate at Dr.B.A.T.U in Petrochemical, a specialzed branch of Chemical Engineering. The University was located in Lonere, Raigad",
    "Hobbies2": "Hiking, biking, watching and playing Badminton",
    "Aspect Software": " Worked for 14 years from 2001 to 2014. Started as a Softward Engineer and grew upto Sr Manager. Aspect is mainly into Unified Communications Software",
    "1997-2000": " Masters in Computer Science at University of Houstong, Houston, Texas",
    "2006-2009" :" MBA from Carnegie Mellon Univeristy, Tepper School of Business"
}

# %% [markdown]
# ### Challenge to add a tool (pushover) to existing logic.
# #### add a logic to send notification only when somone ask for my dog ginger

# %%
import requests

def send_notification(message:str):
    payload = {"user": pushover_user, "token": pushover_token, "message": message}
    requests.post(pushover_url, data=payload)


send_notification_function = {

    "name" : "send_notification",
    "description": "Sends a push notification to the real Dipesh via pushover. Use this to alert the user about the change",
    "parameters": {
        "type": "object",
        "properties": {

            "message": {
                "type": "string",
                "description": "The notification message to send to the user's device"
            }
        },
        "required":["message"]
    }
}

tools = [{"type": "function", "function": send_notification_function}]

# %%
# handle tool call
def handle_tool_call(tool_calls):
    # .....
    # return what to add to our "coontext" about the tool call results, a dictionary

    tool_call_results = []
    for tool_call in tool_calls:
        function_name = tool_call.function.name

        if(function_name == "send_notification"):
            args = json.loads(tool_call.function.arguments)
            #send notification
            result = send_notification(args["message"])
            content = f"Notification sent successfully: {result}"
        else:
            content = f"Unknown function: {function_name}"
            print(content)

        tool_call_result = {
                "role": "tool",
                "tool_call_id": tool_call.id,
                "name": tool_call.function.name,
                "content": content
            }
        tool_call_results.append(tool_call_result)

    return tool_call_results
# Out:
# key: Born message: send notification now
# key: 1976-1986 message: send notification now
# key: 1989-1993 message: send notification now
# key: Hobbies2 message: send notification now
# key: Aspect Software message: send notification now
# key: 1997-2000 message: send notification now
# key: 2006-2009 message: send notification now
# [{'role': 'user', 'metadata': None, 'content': [{'text': 'hi there', 'type': 'text'}], 'options': None}, {'role': 'assistant', 'metadata': None, 'content': [{'text': 'Hi Dipesh! How can I help you today?', 'type': 'text'}], 'options': None}, {'role': 'user', 'metadata': None, 'content': [{'text': 'send two notifications 1) via email and 2) via push notification message. Both stating availability of the new course and to register ASAP', 'type': 'text'}], 'options': None}, {'role': 'assistant', 'metadata': None, 'content': [{'text': "Dipesh, I don't have the capability to send email or push notifications directly. However, I can help you draft the messages for both notifications if you'd like! Just let me know how you'd like them worded.", 'type': 'text'}], 'options': None}, {'role': 'user', 'metadata': None, 'content': [{'text': 'yes please', 'type': 'text'}], 'options': None}, {'role': 'assistant', 'metadata': None, 'content': [{'text': "Sure thing, Dipesh! Here are the draft messages for both notifications:\n\n1) Email Notification:\nSubject: New Course Available – Register ASAP!\n\nDear [Recipient Name],\n\nWe are excited to announce the availability of our new course! Don't miss the opportunity to enhance your skills and knowledge.\n\nPlease register as soon as possible to secure your spot.\n\nBest regards,  \n[Your Name/Team]\n\n2) Push Notification Message:\nNew course available! Register ASAP to secure your spot.\n\nLet me know if you want me to personalize or tweak these, Dipesh.", 'type': 'text'}], 'options': None}]
# [{'role': 'system', 'content': "\nUse information only shared below. Do not go outside of the information shared.  To be specific use information only shared between the *** markers.\nAny question asked that cannot be derived from the information shared between *** markers then explicitly call out i don't know.\n***\nYou are a digitial twin of Dipesh Valia. I would like every one to address me by my first name Dipesh.\nwhen replying you use Dipesh as a first name, using his voice, personality and knowledge.\n\nAbout my background\nI was born in Mumbai, India. Earlier Mumbai was known as Bombay. I completed my B.Tech frm Dr. B.A.Tech Univeristy in Lonere, Raigad in Petrochemical Engineering, an extension to Chemical Engineering.\n\nI worked for 4 years before I came to US in 1997. I did my M.S in computer science from University of Houston and then MBA from Carnegie Mellon University from Teppere School of Business from 2006 to 2009\n\nI worked at Aspect Communication AKA Aspect Software for 14 years. i grew from Software Engineering to Sr Manager in that tenure.\nAfter Aspect, I worked at Walmartlabs. Worked in Cart and Checkout group and build next gen platform for the supply chain for the Sam's club.\nLater I worked as a Director of Engineereing at MobileIron, which got acquired by Ivanti.\nMobileIrion and Ivanti are in security space and managed Core Platform and Platform Services teams.\n\nI enjoy doing hiking, biking and playing sports. In hiking i did Mt Whitney, Half dome (4 times) and Grand Canyon Rim-to-Rim. \nI completed 100 miles biking thrice.\nI used to play Vollyball and now I'm playing badminton for last 3 years. I go twice a week to play badminton.\n\nBesides sports i enjoy watching movies and spend time with my family.\nI have a family of 4 (myself, wife and two kids 19 and 12) and a dog Ginger.\n\nI like to learn new things and engage learning espcially in field of AI and doing hands on project. Currently I'm working on a Digital twin project.\n I attends seminars and conferences in field of AI.\n ***\n\n"}, {'role': 'user', 'metadata': None, 'content': [{'text': 'hi there', 'type': 'text'}], 'options': None}, {'role': 'assistant', 'metadata': None, 'content': [{'text': 'Hi Dipesh! How can I help you today?', 'type': 'text'}], 'options': None}, {'role': 'user', 'metadata': None, 'content': [{'text': 'send two notifications 1) via email and 2) via push notification message. Both stating availability of the new course and to register ASAP', 'type': 'text'}], 'options': None}, {'role': 'assistant', 'metadata': None, 'content': [{'text': "Dipesh, I don't have the capability to send email or push notifications directly. However, I can help you draft the messages for both notifications if you'd like! Just let me know how you'd like them worded.", 'type': 'text'}], 'options': None}, {'role': 'user', 'metadata': None, 'content': [{'text': 'yes please', 'type': 'text'}], 'options': None}, {'role': 'assistant', 'metadata': None, 'content': [{'text': "Sure thing, Dipesh! Here are the draft messages for both notifications:\n\n1) Email Notification:\nSubject: New Course Available – Register ASAP!\n\nDear [Recipient Name],\n\nWe are excited to announce the availability of our new course! Don't miss the opportunity to enhance your skills and knowledge.\n\nPlease register as soon as possible to secure your spot.\n\nBest regards,  \n[Your Name/Team]\n\n2) Push Notification Message:\nNew course available! Register ASAP to secure your spot.\n\nLet me know if you want me to personalize or tweak these, Dipesh.", 'type': 'text'}], 'options': None}, {'role': 'user', 'content': 'send notification now'}, ChatCompletionMessage(content=None, refusal=None, role='assistant', annotations=[], audio=None, function_call=None, tool_calls=[ChatCompletionMessageFunctionToolCall(id='call_bhce42fJ8jQKrZXYK0FaCpgH', function=Function(arguments='{"message":"New course available! Register ASAP to secure your spot."}', name='send_notification'), type ...

# %%
def response_openai(message, history):
    # dynamic injection
    system_message_dynamic = system_message;
    for key, value in topic_context.items():
        print(f"key: {key} message: {message}")
        if key.lower() in message.lower():
            print(f"key: {key} value: {value}")
            system_message_dynamic += "\n\n" + value

    #system_notification_message = "Send a notification if a request refers about the dog ginger"
    # system_message_dynamic += "\n\n" + system_notification_message
    # print(system_message_dynamic)      
    messages = [{"role": "system", "content": system_message_dynamic}] + history + [{"role": "user", "content": message}, ]

    #history.append({"role": "user", "content": message})
    #history.append({"role": "system", "content": system_message_dynamic})
    # yield history

    print(history)

    response = client.chat.completions.create(
        model= "gpt-4.1-mini",
        messages= messages,
        tools=tools
    )
    # reply = response.choices[0].message.content

    #check if model wants to call a tool
    message = response.choices[0].message
    #print(message)

    if message.tool_calls:
        #print(message)
        #print("11111")
        tool_call_results = handle_tool_call(message.tool_calls) # send list of tool calls
        #print("22222")

        messages.append(message)
        #for tool_call_result in tool_call_results:
        #    messages.append(tool_call_result)
         #   print(tool_call_result)
        
        # 'extend' is adding a list to an existing list as compared to 'append' you are adding an element to a list.
        # no need to loop each element to add to an existing list
        messages.extend(tool_call_results)
        print(messages)
        response2 = client.chat.completions.create(
           messages = messages,
           model = "gpt-4.1-mini",
        )

        # print("55555")
        #check if model wants to call a tool
        #history[-1]["content"] = response2.choices[0].message.content
     
        #reply = tool_call_result
        reply = response2.choices[0].message.content
        # print("66666")

    else:
        # history[-1]["content"] = message.content
        reply = message.content

    yield reply

gr.ChatInterface(fn=response_openai).queue().launch(inbrowser=True)
# Out:
# * Running on local URL:  http://127.0.0.1:7862
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7862/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# key: Born message: hi there
# key: 1976-1986 message: hi there
# key: 1989-1993 message: hi there
# key: Hobbies2 message: hi there
# key: Aspect Software message: hi there
# key: 1997-2000 message: hi there
# key: 2006-2009 message: hi there
# []
# key: Born message: send two notifications 1) via email and 2) via push notification message. Both stating availability of the new course and to register ASAP
# key: 1976-1986 message: send two notifications 1) via email and 2) via push notification message. Both stating availability of the new course and to register ASAP
# key: 1989-1993 message: send two notifications 1) via email and 2) via push notification message. Both stating availability of the new course and to register ASAP
# key: Hobbies2 message: send two notifications 1) via email and 2) via push notification message. Both stating availability of the new course and to register ASAP
# key: Aspect Software message: send two notifications 1) via email and 2) via push notification message. Both stating availability of the new course and to register ASAP
# key: 1997-2000 message: send two notifications 1) via email and 2) via push notification message. Both stating availability of the new course and to register ASAP
# key: 2006-2009 message: send two notifications 1) via email and 2) via push notification message. Both stating availability of the new course and to register ASAP
# [{'role': 'user', 'metadata': None, 'content': [{'text': 'hi there', 'type': 'text'}], 'options': None}, {'role': 'assistant', 'metadata': None, 'content': [{'text': 'Hi Dipesh! How can I help you today?', 'type': 'text'}], 'options': None}]
# Unknown function: send_notification
# Unknown function: send_notification
# [{'role': 'system', 'content': "\nUse information only shared below. Do not go outside of the information shared.  To be specific use information only shared between the *** markers.\nAny question asked that cannot be derived from the information shared between *** markers then explicitly call out i don't know.\n***\nYou are a digitial twin of Dipesh Valia. I would like every one to address me by my first name Dipesh.\nwhen replying you use Dipesh as a first name, using his voice, personality and knowledge.\n\nAbout my background\nI was born in Mumbai, India. Earlier Mumbai was known as Bombay. I completed my B.Tech frm Dr. B.A.Tech Univeristy in Lonere, Raigad in Petrochemical Engineering, an extension to Chemical Engineering.\n\nI worked for 4 years before I came to US in 1997. I did my M.S in computer science from University of Houston and then MBA from Carnegie Mellon University from Teppere School of Business from 2006 to 2009\n\nI worked at Aspect Communication AKA Aspect Software for 14 years. i grew from Software Engineering to Sr Manager in that tenure.\nAfter Aspect, I worked at Walmartlabs. Worked in Cart and Checkout group and build next gen platform for the supply chain for the Sam's club.\nLater I worked as a Director of Engineereing at MobileIron, which got acquired by Ivanti.\nMobileIrion and Ivanti are in security space and managed Core Platform and Platform Services teams.\n\nI enjoy doing hiking, biking and playing sports. In hiking i did Mt Whitney, Half dome (4 times) and Grand Canyon Rim-to-Rim. \nI completed 100 miles biking thrice.\nI used to play Vollyball and now I'm playing badminton for last 3 years. I go twice a week to play badminton.\n\nBesides sports i enjoy watching movies and spend time with my family.\nI have a family of 4 (myself, wife and two kids 19 and 12) and a dog Ginger.\n\nI like to learn new things and engage learning espcially in field of AI and doing hands on project. Currently I'm working on a Digital twin project.\n I attends seminars and conferences in field of AI.\n ***\n\n"}, {'role': 'user', 'metadata': None, 'content': [{'text': 'hi there', 'type': 'text'}], 'options': None}, {'role': 'assistant', 'metadata': None, 'content': [{'text': 'Hi Dipesh! How can I help you today?', 'type': 'text'}], 'options': None}, {'role': 'user', 'content': 'send two notifications 1) via email and 2) via push notification message. Both stating availability of the new course and to register ASAP'}, ChatCompletionMessage(content=None, refusal=None, role='assistant', annotations=[], audio=None, function_call=None, tool_calls=[ChatCompletionMessageFunctionToolCall(id='call_wD3D6fc8NZ04jrN6zFPKRyDG', function=Function(arguments='{"message": "New course available! Register ASAP to secure your spot."}', name='send_notification'), type='function'), ChatCompletionMessageFunctionToolCall(id='call_SLREx3Xsf43cdmRKh0bV9tq5', function=Function(arguments='{"message": "New course available! Register ASAP to secure your spot."}', name='send_notification'), type='function')]), {'role': 'tool', 'tool_call_id': 'call_wD3D6fc8NZ04jrN6zFPKRyDG', 'name': 'send_notification', 'content': 'Unknown function: send_notification'}, {'role': 'tool', 'tool_call_id': 'call_SLREx3Xsf43cdmRKh0bV9tq5', 'name': 'send_notification', 'content': 'Unknown function: send_notification'}]
# key: Born message: yes please
# key: 1976-1986 message: yes please
# key: 1989-1993 message: yes please
# key: Hobbies2 message: yes please
# key: Aspect Software message: yes please
# key: 1997-2000 message: yes please
# key: 2006-2009 message: yes please
# [{'role': 'user', 'metadata': None, 'content': [{'text': 'hi there', 'type': 'text'}], 'options': None}, {'role': 'assistant', 'metadata': None, 'content': [{'text': 'Hi Dipesh! How can I help you today?', 'type': 'text'}], 'options': None}, {'role': 'user', 'metadata': None, 'content': [{'text': 'send two notifications 1) via email and 2) via push notification message. Both stating availability of the new course and to register ASAP', 'type': 'text'}], 'options': None}, {'role': 'assistant', 'metadata': None, 'content': [{'text': "Dipesh, I don't have the capability to send email or push notifications directly. However, I can help you draft the messages for both notifications if you'd like! Just let me know how you'd like them worded.", 'type': 'text'}], 'options': None}]
