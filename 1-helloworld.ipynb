# %% [markdown]
# Step 1: Import Libraries and load the environment variables

# %%
import os
from openai import OpenAI
from dotenv import load_dotenv

# %%
load_dotenv()
OPENAI_API_KEY = os.getenv("OPENAI_API_KEY")

if OPENAI_API_KEY is None:
    raise Exception ("API key is missing.")
else:
    print(OPENAI_API_KEY[:8])
# Out:
# sk-proj-

# %% [markdown]
# ## Step2: Call the API

# %%
client = OpenAI()

response = client.chat.completions.create(
    model="gpt-4.1-mini",
    messages=[{"role":"user", "content": "who won the cricket T20 world cup in 2026"}]
)

answer = response.choices[0].message.content
print(answer)
# Out:
# I’m unable to provide information about the winner of the 2026 T20 Cricket World Cup as my training only includes data up to June 2024. You might want to check the latest sports news or official cricket sources for the most current results.
